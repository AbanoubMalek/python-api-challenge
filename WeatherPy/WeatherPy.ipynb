# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 567

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather"
base_url = "http://api.openweathermap.org/geo/1.0/direct?q="


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'{base_url}{city}&appid={weather_api_key}'

    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_resp = requests.get(city_url).json()
        city_url = f'{url}?lat={city_resp[0]["lat"]}&lon={city_resp[0]["lon"]}&appid={weather_api_key}'
        city_weather = requests.get(city_url).json()
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max'] - 273.15
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto el triunfo
# Processing Record 2 of Set 1 | olonkinbyen
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | tahe
# Processing Record 5 of Set 1 | beau vallon
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | adamstown
# Processing Record 8 of Set 1 | iqaluit
# Processing Record 9 of Set 1 | waitangi
# Processing Record 10 of Set 1 | bethel
# Processing Record 11 of Set 1 | port mathurin
# Processing Record 12 of Set 1 | yuzhno-kurilsk
# Processing Record 13 of Set 1 | puerto natales
# Processing Record 14 of Set 1 | touros
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | blackmans bay
# Processing Record 17 of Set 1 | papatowai
# Processing Record 18 of Set 1 | lebu
# Processing Record 19 of Set 1 | thompson
# Processing Record 20 of Set 1 | utrik
# City not found. Skipping...
# Processing Record 21 of Set 1 | cambria
# Processing Record 22 of Set 1 | cargados carajos
# City not found. Skipping...
# Processing Record 23 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 24 of Set 1 | iskateley
# Processing Record 25 of Set 1 | ilulissat
# Processing Record 26 of Set 1 | takamaka
# Processing Record 27 of Set 1 | sadjoavato
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | grytviken
# Processing Record 30 of Set 1 | whangarei
# Processing Record 31 of Set 1 | whitehorse
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | bilibino
# Processing Record 34 of Set 1 | morant bay
# Processing Record 35 of Set 1 | tura
# Processing Record 36 of Set 1 | egilsstadir
# Processing Record 37 of Set 1 | ayacucho
# Processing Record 38 of Set 1 | tolanaro
# Processing Record 39 of Set 1 | kavaratti
# Processing Record 40 of Set 1 | aasiaat
# Processing Record 41 of Set 1 | atafu village
# City not found. Skipping...
# Processing Record 42 of Set 1 | zambezi
# Processing Record 43 of Set 1 | avarua
# Processing Record 44 of Set 1 | invercargill
# Processing Record 45 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 46 of Set 1 | bridgewater
# Processing Record 47 of Set 1 | longyearbyen
# Processing Record 48 of Set 1 | hamilton
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | dryden
# Processing Record 0 of Set 2 | goundi
# Processing Record 1 of Set 2 | enewetak
# Processing Record 2 of Set 2 | tobi village
# City not found. Skipping...
# Processing Record 3 of Set 2 | svetlyy yar
# Processing Record 4 of Set 2 | geraldton
# Processing Record 5 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 6 of Set 2 | hailar
# Processing Record 7 of Set 2 | alotau
# Processing Record 8 of Set 2 | puerto ayacucho
# Processing Record 9 of Set 2 | port lincoln
# Processing Record 10 of Set 2 | isangel
# Processing Record 11 of Set 2 | ghat
# Processing Record 12 of Set 2 | port saint john's
# City not found. Skipping...
# Processing Record 13 of Set 2 | buala
# Processing Record 14 of Set 2 | zhezqazghan
# Processing Record 15 of Set 2 | puerto san carlos
# Processing Record 16 of Set 2 | edinburgh of the seven seas
# Processing Record 17 of Set 2 | cill airne
# Processing Record 18 of Set 2 | tazovsky
# Processing Record 19 of Set 2 | monrovia
# Processing Record 20 of Set 2 | tvoroyri
# Processing Record 21 of Set 2 | westport
# Processing Record 22 of Set 2 | katsuren-haebaru
# City not found. Skipping...
# Processing Record 23 of Set 2 | college
# Processing Record 24 of Set 2 | taoudenni
# Processing Record 25 of Set 2 | vorgashor
# Processing Record 26 of Set 2 | lihue
# Processing Record 27 of Set 2 | tiksi
# Processing Record 28 of Set 2 | saipan
# Processing Record 29 of Set 2 | lautoka
# Processing Record 30 of Set 2 | warmbaths
# City not found. Skipping...
# Processing Record 31 of Set 2 | las palmas
# Processing Record 32 of Set 2 | chamzinka
# Processing Record 33 of Set 2 | mirny
# Processing Record 34 of Set 2 | ain leuh
# Processing Record 35 of Set 2 | zeya
# Processing Record 36 of Set 2 | west island
# Processing Record 37 of Set 2 | cuito
# Processing Record 38 of Set 2 | remire-montjoly
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | hawaiian paradise park
# Processing Record 41 of Set 2 | linhares
# Processing Record 42 of Set 2 | nukunonu
# Processing Record 43 of Set 2 | sorong
# Processing Record 44 of Set 2 | 'ohonua
# Processing Record 45 of Set 2 | anadyr
# Processing Record 46 of Set 2 | acarau
# Processing Record 47 of Set 2 | lhokseumawe
# Processing Record 48 of Set 2 | merritt island
# Processing Record 49 of Set 2 | constantia
# Processing Record 0 of Set 3 | bardai
# Processing Record 1 of Set 3 | mount pearl
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | horta
# Processing Record 4 of Set 3 | pielavesi
# Processing Record 5 of Set 3 | ribeira grande
# Processing Record 6 of Set 3 | margaret river
# Processing Record 7 of Set 3 | susuman
# Processing Record 8 of Set 3 | ciudad lazaro cardenas
# Processing Record 9 of Set 3 | boguchany
# Processing Record 10 of Set 3 | shofirkon shahri
# City not found. Skipping...
# Processing Record 11 of Set 3 | coquimbo
# Processing Record 12 of Set 3 | arraial do cabo
# Processing Record 13 of Set 3 | castlegar
# Processing Record 14 of Set 3 | holualoa
# Processing Record 15 of Set 3 | jamestown
# Processing Record 16 of Set 3 | alice springs
# Processing Record 17 of Set 3 | zhaotong
# Processing Record 18 of Set 3 | la ronge
# Processing Record 19 of Set 3 | muang phon-hong
# City not found. Skipping...
# Processing Record 20 of Set 3 | tralee
# Processing Record 21 of Set 3 | boone
# Processing Record 22 of Set 3 | newman
# Processing Record 23 of Set 3 | bomi
# Processing Record 24 of Set 3 | coswig
# Processing Record 25 of Set 3 | ouellah
# City not found. Skipping...
# Processing Record 26 of Set 3 | east london
# Processing Record 27 of Set 3 | barlig
# Processing Record 28 of Set 3 | hefei
# Processing Record 29 of Set 3 | dalcahue
# Processing Record 30 of Set 3 | san pedro pochutla
# Processing Record 31 of Set 3 | polyarnyy
# City not found. Skipping...
# Processing Record 32 of Set 3 | lake havasu city
# Processing Record 33 of Set 3 | talnakh
# Processing Record 34 of Set 3 | wynyard
# Processing Record 35 of Set 3 | madalena
# Processing Record 36 of Set 3 | badger
# Processing Record 37 of Set 3 | vadso
# Processing Record 38 of Set 3 | nemuro
# Processing Record 39 of Set 3 | sarigerme
# Processing Record 40 of Set 3 | keflavik
# Processing Record 41 of Set 3 | sitka
# Processing Record 42 of Set 3 | itaueira
# Processing Record 43 of Set 3 | st. john's
# Processing Record 44 of Set 3 | lucapa
# Processing Record 45 of Set 3 | alamo
# Processing Record 46 of Set 3 | dunedin
# Processing Record 47 of Set 3 | zhigalovo
# Processing Record 48 of Set 3 | darwin
# Processing Record 49 of Set 3 | nuku'alofa
# Processing Record 0 of Set 4 | tshikapa
# Processing Record 1 of Set 4 | isafjordur
# Processing Record 2 of Set 4 | lompoc
# Processing Record 3 of Set 4 | ocean pointe
# City not found. Skipping...
# Processing Record 4 of Set 4 | callao
# Processing Record 5 of Set 4 | los andes
# Processing Record 6 of Set 4 | miquelon
# Processing Record 7 of Set 4 | puerto colombia
# Processing Record 8 of Set 4 | antalaha
# Processing Record 9 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 10 of Set 4 | yellowknife
# Processing Record 11 of Set 4 | poronaysk
# Processing Record 12 of Set 4 | banfora
# Processing Record 13 of Set 4 | trinidad
# Processing Record 14 of Set 4 | kapuskasing
# Processing Record 15 of Set 4 | masvingo
# Processing Record 16 of Set 4 | el granada
# Processing Record 17 of Set 4 | phan rang-thap cham
# Processing Record 18 of Set 4 | kununurra
# Processing Record 19 of Set 4 | road town
# Processing Record 20 of Set 4 | klyuchi
# Processing Record 21 of Set 4 | stanley
# Processing Record 22 of Set 4 | enshi
# Processing Record 23 of Set 4 | septemvri
# Processing Record 24 of Set 4 | langsa
# Processing Record 25 of Set 4 | cidreira
# Processing Record 26 of Set 4 | chernyshevskiy
# Processing Record 27 of Set 4 | weno
# Processing Record 28 of Set 4 | fuvahmulah
# Processing Record 29 of Set 4 | camiri
# Processing Record 30 of Set 4 | roma
# Processing Record 31 of Set 4 | quellon
# Processing Record 32 of Set 4 | magadan
# Processing Record 33 of Set 4 | igarka
# Processing Record 34 of Set 4 | reggane
# Processing Record 35 of Set 4 | fort bragg
# Processing Record 36 of Set 4 | slavgorod
# Processing Record 37 of Set 4 | ji parana
# Processing Record 38 of Set 4 | colares
# Processing Record 39 of Set 4 | san antonio de pale
# Processing Record 40 of Set 4 | caleta de carquin
# Processing Record 41 of Set 4 | balabac
# Processing Record 42 of Set 4 | aguilar de campoo
# Processing Record 43 of Set 4 | kodiak
# Processing Record 44 of Set 4 | udachny
# Processing Record 45 of Set 4 | neiafu
# Processing Record 46 of Set 4 | dire dawa
# Processing Record 47 of Set 4 | kodinsk
# Processing Record 48 of Set 4 | lorengau
# Processing Record 49 of Set 4 | el haouaria
# Processing Record 0 of Set 5 | palmer
# Processing Record 1 of Set 5 | lufilufi
# City not found. Skipping...
# Processing Record 2 of Set 5 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 3 of Set 5 | lamu
# Processing Record 4 of Set 5 | baoro
# Processing Record 5 of Set 5 | merizo village
# City not found. Skipping...
# Processing Record 6 of Set 5 | tsiombe
# City not found. Skipping...
# Processing Record 7 of Set 5 | cable beach
# Processing Record 8 of Set 5 | yunyang
# Processing Record 9 of Set 5 | hithadhoo
# Processing Record 10 of Set 5 | borba
# Processing Record 11 of Set 5 | kigoma
# Processing Record 12 of Set 5 | kingston
# Processing Record 13 of Set 5 | kuanda
# Processing Record 14 of Set 5 | chonchi
# Processing Record 15 of Set 5 | markovo
# Processing Record 16 of Set 5 | itaunja
# City not found. Skipping...
# Processing Record 17 of Set 5 | belmonte
# Processing Record 18 of Set 5 | benghazi
# Processing Record 19 of Set 5 | napili-honokowai
# City not found. Skipping...
# Processing Record 20 of Set 5 | wailua homesteads
# Processing Record 21 of Set 5 | lenger
# Processing Record 22 of Set 5 | el calafate
# Processing Record 23 of Set 5 | fort st. john
# Processing Record 24 of Set 5 | villa gesell
# Processing Record 25 of Set 5 | luderitz
# Processing Record 26 of Set 5 | salalah
# Processing Record 27 of Set 5 | medyn'
# Processing Record 28 of Set 5 | puerto deseado
# Processing Record 29 of Set 5 | lazaro cardenas
# Processing Record 30 of Set 5 | port elizabeth
# Processing Record 31 of Set 5 | harnosand
# Processing Record 32 of Set 5 | peterhead
# Processing Record 33 of Set 5 | corner brook
# Processing Record 34 of Set 5 | aripuana
# City not found. Skipping...
# Processing Record 35 of Set 5 | bathsheba
# Processing Record 36 of Set 5 | hammerfest
# Processing Record 37 of Set 5 | punta arenas
# Processing Record 38 of Set 5 | uturoa
# Processing Record 39 of Set 5 | kutulik
# Processing Record 40 of Set 5 | ulanhot
# Processing Record 41 of Set 5 | hami
# Processing Record 42 of Set 5 | queenstown
# Processing Record 43 of Set 5 | chinde
# Processing Record 44 of Set 5 | vila franca do campo
# Processing Record 45 of Set 5 | sarangani
# Processing Record 46 of Set 5 | kirakira
# Processing Record 47 of Set 5 | nkhotakota
# Processing Record 48 of Set 5 | tevragh zeina
# Processing Record 49 of Set 5 | tual
# Processing Record 0 of Set 6 | bengkulu
# Processing Record 1 of Set 6 | mount gambier
# Processing Record 2 of Set 6 | forbes
# Processing Record 3 of Set 6 | bathurst
# Processing Record 4 of Set 6 | al miqdadiyah
# Processing Record 5 of Set 6 | ta`u
# City not found. Skipping...
# Processing Record 6 of Set 6 | nar'yan-mar
# Processing Record 7 of Set 6 | kenai
# Processing Record 8 of Set 6 | aweil
# Processing Record 9 of Set 6 | daru
# Processing Record 10 of Set 6 | puerto baquerizo moreno
# Processing Record 11 of Set 6 | coahuayana de hidalgo
# Processing Record 12 of Set 6 | regina
# Processing Record 13 of Set 6 | sinabang
# Processing Record 14 of Set 6 | aldama
# Processing Record 15 of Set 6 | eyl
# Processing Record 16 of Set 6 | cabo san lucas
# Processing Record 17 of Set 6 | severo-yeniseyskiy
# City not found. Skipping...
# Processing Record 18 of Set 6 | dudinka
# Processing Record 19 of Set 6 | waingapu
# Processing Record 20 of Set 6 | opuwo
# Processing Record 21 of Set 6 | hasaki
# Processing Record 22 of Set 6 | moriki
# Processing Record 23 of Set 6 | karamay
# Processing Record 24 of Set 6 | gueltat zemmour
# Processing Record 25 of Set 6 | manokwari
# Processing Record 26 of Set 6 | sussex
# Processing Record 27 of Set 6 | genhe
# Processing Record 28 of Set 6 | ust-nera
# Processing Record 29 of Set 6 | nova sintra
# Processing Record 30 of Set 6 | guerrero negro
# Processing Record 31 of Set 6 | puerto quijarro
# Processing Record 32 of Set 6 | zaragoza
# Processing Record 33 of Set 6 | tataouine
# Processing Record 34 of Set 6 | la foa
# Processing Record 35 of Set 6 | kansk
# Processing Record 36 of Set 6 | talcahuano
# Processing Record 37 of Set 6 | calvinia
# Processing Record 38 of Set 6 | rongelap
# Processing Record 39 of Set 6 | villa ojo de agua
# Processing Record 40 of Set 6 | karagandy
# Processing Record 41 of Set 6 | new norfolk
# Processing Record 42 of Set 6 | carnarvon
# Processing Record 43 of Set 6 | san juan
# Processing Record 44 of Set 6 | port douglas
# Processing Record 45 of Set 6 | attapeu
# Processing Record 46 of Set 6 | essaouira
# Processing Record 47 of Set 6 | toropets
# Processing Record 48 of Set 6 | rubtsovsk
# Processing Record 49 of Set 6 | ust'-kut
# Processing Record 0 of Set 7 | pandan
# Processing Record 1 of Set 7 | vorkuta
# Processing Record 2 of Set 7 | kashiwazaki
# Processing Record 3 of Set 7 | mokhsogollokh
# Processing Record 4 of Set 7 | chifeng
# Processing Record 5 of Set 7 | ulsteinvik
# Processing Record 6 of Set 7 | kaynarca
# Processing Record 7 of Set 7 | tanrake village
# City not found. Skipping...
# Processing Record 8 of Set 7 | ahau
# Processing Record 9 of Set 7 | gadzhiyevo
# Processing Record 10 of Set 7 | kuching
# Processing Record 11 of Set 7 | jurm
# Processing Record 12 of Set 7 | qulsary
# City not found. Skipping...
# Processing Record 13 of Set 7 | khash
# Processing Record 14 of Set 7 | mejit
# Processing Record 15 of Set 7 | haiku-pauwela
# City not found. Skipping...
# Processing Record 16 of Set 7 | qaqortoq
# Processing Record 17 of Set 7 | adre
# Processing Record 18 of Set 7 | talcher
# Processing Record 19 of Set 7 | bankim
# Processing Record 20 of Set 7 | saint-pol-de-leon
# Processing Record 21 of Set 7 | lekki
# Processing Record 22 of Set 7 | noosa heads
# Processing Record 23 of Set 7 | stepnogorsk
# Processing Record 24 of Set 7 | happy valley-goose bay
# Processing Record 25 of Set 7 | south hedland
# Processing Record 26 of Set 7 | sola
# Processing Record 27 of Set 7 | vilyuchinsk
# Processing Record 28 of Set 7 | umm ruwaba
# Processing Record 29 of Set 7 | ardestan
# Processing Record 30 of Set 7 | gisborne
# Processing Record 31 of Set 7 | kerikeri
# Processing Record 32 of Set 7 | le port
# Processing Record 33 of Set 7 | oranjemund
# Processing Record 34 of Set 7 | kenora
# Processing Record 35 of Set 7 | olyokminsk
# Processing Record 36 of Set 7 | spring creek
# Processing Record 37 of Set 7 | vila velha
# Processing Record 38 of Set 7 | ghanzi
# Processing Record 39 of Set 7 | piti village
# City not found. Skipping...
# Processing Record 40 of Set 7 | nuuk
# Processing Record 41 of Set 7 | lata
# Processing Record 42 of Set 7 | tromso
# Processing Record 43 of Set 7 | nelson bay
# Processing Record 44 of Set 7 | teguise
# Processing Record 45 of Set 7 | cottage grove
# Processing Record 46 of Set 7 | medina
# Processing Record 47 of Set 7 | pont rouge
# Processing Record 48 of Set 7 | bazar-korgon
# Processing Record 49 of Set 7 | sant antoni de portmany
# Processing Record 0 of Set 8 | kone
# Processing Record 1 of Set 8 | north platte
# Processing Record 2 of Set 8 | zapala
# Processing Record 3 of Set 8 | kailua-kona
# Processing Record 4 of Set 8 | praia da vitoria
# Processing Record 5 of Set 8 | gorontalo
# Processing Record 6 of Set 8 | privolzhskiy
# Processing Record 7 of Set 8 | sretensk
# Processing Record 8 of Set 8 | pocoes
# Processing Record 9 of Set 8 | grand baie
# Processing Record 10 of Set 8 | mugia
# Processing Record 11 of Set 8 | dalandzadgad
# City not found. Skipping...
# Processing Record 12 of Set 8 | sao vicente
# Processing Record 13 of Set 8 | arar
# Processing Record 14 of Set 8 | nantucket
# Processing Record 15 of Set 8 | lewistown
# Processing Record 16 of Set 8 | ponta delgada
# Processing Record 17 of Set 8 | sobrance
# Processing Record 18 of Set 8 | colonia
# Processing Record 19 of Set 8 | bequimao
# Processing Record 20 of Set 8 | sinop
# Processing Record 21 of Set 8 | lucas
# Processing Record 22 of Set 8 | vikhorevka
# Processing Record 23 of Set 8 | saldanha
# Processing Record 24 of Set 8 | peniche
# Processing Record 25 of Set 8 | island harbour
# Processing Record 26 of Set 8 | argo
# Processing Record 27 of Set 8 | yuanping
# Processing Record 28 of Set 8 | kurumkan
# Processing Record 29 of Set 8 | san patricio
# Processing Record 30 of Set 8 | kupang
# Processing Record 31 of Set 8 | marshall
# Processing Record 32 of Set 8 | pacific grove
# Processing Record 33 of Set 8 | veraval
# Processing Record 34 of Set 8 | arvayheer
# City not found. Skipping...
# Processing Record 35 of Set 8 | tinajo
# Processing Record 36 of Set 8 | tangalle
# Processing Record 37 of Set 8 | ayr
# Processing Record 38 of Set 8 | viedma
# Processing Record 39 of Set 8 | dar chioukh
# Processing Record 40 of Set 8 | aioun
# Processing Record 41 of Set 8 | swan hill
# Processing Record 42 of Set 8 | yreka
# Processing Record 43 of Set 8 | tofol
# Processing Record 44 of Set 8 | savave village
# City not found. Skipping...
# Processing Record 45 of Set 8 | nogliki
# Processing Record 46 of Set 8 | oualidia
# Processing Record 47 of Set 8 | belyye vody
# City not found. Skipping...
# Processing Record 48 of Set 8 | nadym
# Processing Record 49 of Set 8 | shohimardon
# Processing Record 0 of Set 9 | sale
# Processing Record 1 of Set 9 | faya-largeau
# Processing Record 2 of Set 9 | guilin
# Processing Record 3 of Set 9 | celestun
# Processing Record 4 of Set 9 | nova vicosa
# Processing Record 5 of Set 9 | myeik
# Processing Record 6 of Set 9 | i-n-salah
# City not found. Skipping...
# Processing Record 7 of Set 9 | berezovyy
# Processing Record 8 of Set 9 | ippy
# Processing Record 9 of Set 9 | kruisfontein
# Processing Record 10 of Set 9 | hilo
# Processing Record 11 of Set 9 | shenjiamen
# Processing Record 12 of Set 9 | san carlos
# Processing Record 13 of Set 9 | sisimiut
# Processing Record 14 of Set 9 | coxim
# Processing Record 15 of Set 9 | charlestown
# Processing Record 16 of Set 9 | balnearia
# Processing Record 17 of Set 9 | st johnsbury
# Processing Record 18 of Set 9 | tibati
# Processing Record 19 of Set 9 | usogorsk
# Processing Record 20 of Set 9 | port hueneme
# Processing Record 21 of Set 9 | ahar
# Processing Record 22 of Set 9 | luanda
# Processing Record 23 of Set 9 | dalbandin
# Processing Record 24 of Set 9 | salekhard
# Processing Record 25 of Set 9 | kokshetau
# Processing Record 26 of Set 9 | namibe
# Processing Record 27 of Set 9 | simpang
# Processing Record 28 of Set 9 | vinh yen
# Processing Record 29 of Set 9 | chibougamau
# Processing Record 30 of Set 9 | papao
# Processing Record 31 of Set 9 | vallenar
# Processing Record 32 of Set 9 | charters towers
# Processing Record 33 of Set 9 | isiro
# Processing Record 34 of Set 9 | afaahiti
# Processing Record 35 of Set 9 | al jawf
# Processing Record 36 of Set 9 | imbituba
# Processing Record 37 of Set 9 | sur
# Processing Record 38 of Set 9 | kalkaman
# Processing Record 39 of Set 9 | espargos
# Processing Record 40 of Set 9 | pavlodar
# Processing Record 41 of Set 9 | mujiayingzi
# Processing Record 42 of Set 9 | varkaus
# Processing Record 43 of Set 9 | benavente
# Processing Record 44 of Set 9 | pagadian
# Processing Record 45 of Set 9 | cockburn town
# Processing Record 46 of Set 9 | akhty
# Processing Record 47 of Set 9 | ksar chellala
# Processing Record 48 of Set 9 | tabou
# Processing Record 49 of Set 9 | pisco
# Processing Record 0 of Set 10 | launceston
# Processing Record 1 of Set 10 | asha
# Processing Record 2 of Set 10 | sierra grande
# Processing Record 3 of Set 10 | los angeles
# Processing Record 4 of Set 10 | sao felipe
# Processing Record 5 of Set 10 | bonthe
# Processing Record 6 of Set 10 | kandahar
# Processing Record 7 of Set 10 | cadale
# Processing Record 8 of Set 10 | arkhangel'sk
# City not found. Skipping...
# Processing Record 9 of Set 10 | namsos
# Processing Record 10 of Set 10 | punta cardon
# Processing Record 11 of Set 10 | acapulco de juarez
# Processing Record 12 of Set 10 | saint-joseph
# Processing Record 13 of Set 10 | luganville
# Processing Record 14 of Set 10 | fale old settlement
# City not found. Skipping...
# Processing Record 15 of Set 10 | vernon
# Processing Record 16 of Set 10 | oruro
# Processing Record 17 of Set 10 | hastings
# Processing Record 18 of Set 10 | luau
# Processing Record 19 of Set 10 | ketchikan
# Processing Record 20 of Set 10 | midland
# Processing Record 21 of Set 10 | saint-philippe
# Processing Record 22 of Set 10 | mandali
# Processing Record 23 of Set 10 | ust-tsilma
# Processing Record 24 of Set 10 | taltal
# Processing Record 25 of Set 10 | mersa matruh
# Processing Record 26 of Set 10 | ninghai
# Processing Record 27 of Set 10 | wenling
# Processing Record 28 of Set 10 | alliance
# Processing Record 29 of Set 10 | cam ranh
# Processing Record 30 of Set 10 | casablanca
# Processing Record 31 of Set 10 | puerto del rosario
# Processing Record 32 of Set 10 | bam
# Processing Record 33 of Set 10 | urzhar
# City not found. Skipping...
# Processing Record 34 of Set 10 | am djarass
# Processing Record 35 of Set 10 | kedrovyy
# City not found. Skipping...
# Processing Record 36 of Set 10 | tauranga
# Processing Record 37 of Set 10 | semera
# Processing Record 38 of Set 10 | puerto armuelles
# Processing Record 39 of Set 10 | qamdo
# Processing Record 40 of Set 10 | orchard mesa
# Processing Record 41 of Set 10 | as sulayyil
# Processing Record 42 of Set 10 | ulan bator
# Processing Record 43 of Set 10 | jaicos
# Processing Record 44 of Set 10 | larbaa
# Processing Record 45 of Set 10 | madinat ash shamal
# Processing Record 46 of Set 10 | anshun
# Processing Record 47 of Set 10 | general conesa
# Processing Record 48 of Set 10 | kapa'a
# Processing Record 49 of Set 10 | antsiranana
# Processing Record 0 of Set 11 | marapanim
# Processing Record 1 of Set 11 | selfoss
# Processing Record 2 of Set 11 | wewak
# Processing Record 3 of Set 11 | codrington
# Processing Record 4 of Set 11 | fayzabad
# Processing Record 5 of Set 11 | rio grande
# Processing Record 6 of Set 11 | boundiali
# Processing Record 7 of Set 11 | williams lake
# Processing Record 8 of Set 11 | northam
# Processing Record 9 of Set 11 | yulinshi
# City not found. Skipping...
# Processing Record 10 of Set 11 | kataragama
# Processing Record 11 of Set 11 | bossangoa
# Processing Record 12 of Set 11 | oamaru
# Processing Record 13 of Set 11 | puerto cabezas
# Processing Record 14 of Set 11 | ginir
# Processing Record 15 of Set 11 | arteche
# Processing Record 16 of Set 11 | novodvinsk
# Processing Record 17 of Set 11 | swakopmund
# Processing Record 18 of Set 11 | bol'sherech'ye
# Processing Record 19 of Set 11 | conceicao do araguaia
# Processing Record 20 of Set 11 | nueve de julio
# Processing Record 21 of Set 11 | tukrah
# Processing Record 22 of Set 11 | betio village
# City not found. Skipping...
# Processing Record 23 of Set 11 | witu
# Processing Record 24 of Set 11 | obock
# Processing Record 25 of Set 11 | singaraja
# Processing Record 26 of Set 11 | margate
# Processing Record 27 of Set 11 | mareeba
# Processing Record 28 of Set 11 | wellington
# Processing Record 29 of Set 11 | dahab
# Processing Record 30 of Set 11 | encruzilhada do sul
# Processing Record 31 of Set 11 | alofi
# Processing Record 32 of Set 11 | bamboo flat
# Processing Record 33 of Set 11 | mermoz boabab
# City not found. Skipping...
# Processing Record 34 of Set 11 | podporozh'ye
# City not found. Skipping...
# Processing Record 35 of Set 11 | livingstone
# Processing Record 36 of Set 11 | yaren
# Processing Record 37 of Set 11 | portland
# Processing Record 38 of Set 11 | praia
# Processing Record 39 of Set 11 | howard springs
# Processing Record 40 of Set 11 | tara
# Processing Record 41 of Set 11 | lensk
# Processing Record 42 of Set 11 | malpica
# Processing Record 43 of Set 11 | isla vista
# Processing Record 44 of Set 11 | gebeit
# Processing Record 45 of Set 11 | karkira
# City not found. Skipping...
# Processing Record 46 of Set 11 | huarmey
# Processing Record 47 of Set 11 | aliveri
# Processing Record 48 of Set 11 | ingeniero jacobacci
# Processing Record 49 of Set 11 | cairns city
# Processing Record 0 of Set 12 | khovd
# Processing Record 1 of Set 12 | hadibu
# Processing Record 2 of Set 12 | robore
# Processing Record 3 of Set 12 | laojunmiao
# Processing Record 4 of Set 12 | san luis
# Processing Record 5 of Set 12 | temiskaming shores
# Processing Record 6 of Set 12 | kothi
# Processing Record 7 of Set 12 | fort mcmurray
# Processing Record 8 of Set 12 | mcpherson
# Processing Record 9 of Set 12 | chernomorskoye
# City not found. Skipping...
# Processing Record 10 of Set 12 | niquelandia
# Processing Record 11 of Set 12 | tlacotepec
# Processing Record 12 of Set 12 | calatayud
# Processing Record 13 of Set 12 | beberibe
# Processing Record 14 of Set 12 | rabo de peixe
# Processing Record 15 of Set 12 | pimentel
# Processing Record 16 of Set 12 | aykhal
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          524
# Lat           524
# Lng           524
# Max Temp      524
# Humidity      524
# Cloudiness    524
# Wind Speed    524
# Country       524
# Date          524
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  puerto el triunfo  13.2748  -88.5472     32.59        43          54
# 1        olonkinbyen  70.9224   -8.7160    -11.07        57         100
# 2  port-aux-francais -49.3498   70.2200      8.82        94          97
# 3               tahe  52.3696  124.5765    -19.77        98         100
# 4        beau vallon -20.4298   57.7118     27.23        89          75
#
#    Wind Speed Country        Date
# 0        2.90      SV  1708035967
# 1       11.51      SJ  1708035968
# 2       14.97      TF  1708035968
# 3        0.81      CN  1708035969
# 4        2.06      MU  1708035969

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        puerto el triunfo  13.2748  -88.5472     32.59        43          54
# 1              olonkinbyen  70.9224   -8.7160    -11.07        57         100
# 2        port-aux-francais -49.3498   70.2200      8.82        94          97
# 3                     tahe  52.3696  124.5765    -19.77        98         100
# 4              beau vallon -20.4298   57.7118     27.23        89          75
#
#          Wind Speed Country        Date
# City_ID
# 0              2.90      SV  1708035967
# 1             11.51      SJ  1708035968
# 2             14.97      TF  1708035968
# 3              0.81      CN  1708035969
# 4              2.06      MU  1708035969

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_axis = np.array(city_data_df['Lat'])
y_axis = np.array(city_data_df['Max Temp'])
plt.scatter(x_axis, y_axis, marker="o", edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('City Latitude vs Max Temperature')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_axis = np.array(city_data_df['Lat'])
y_axis = np.array(city_data_df['Humidity'])
plt.scatter(x_axis, y_axis, marker="o", edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs Humidity')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_axis = np.array(city_data_df['Lat'])
y_axis = np.array(city_data_df['Cloudiness'])
plt.scatter(x_axis, y_axis, marker="o", edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs Cloudiness')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_axis = np.array(city_data_df['Lat'])
y_axis = np.array(city_data_df['Wind Speed'])
plt.scatter(x_axis, y_axis, marker="o", edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Latitude vs Wind Speed')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_regress_plot(x_axis, y_axis, xlabel, ylabel, title, x, y):
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    regress_values = x_axis * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_axis, y_axis, marker="o")
    plt.plot(x_axis,regress_values,"r-")
    plt.annotate(line_eq,(x,y),fontsize=15,color="red")
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    print(f'The r-value is: {rvalue}')
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >=0 ]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        puerto el triunfo  13.2748  -88.5472     32.59        43          54
# 1              olonkinbyen  70.9224   -8.7160    -11.07        57         100
# 3                     tahe  52.3696  124.5765    -19.77        98         100
# 7                  iqaluit  63.7494  -68.5219    -16.03        84         100
# 9                   bethel  60.7922 -161.7558     -6.97        93         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.90      SV  1708035967
# 1             11.51      SJ  1708035968
# 3              0.81      CN  1708035969
# 7              3.09      CA  1708035971
# 9              5.66      US  1708035902

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0 ]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        port-aux-francais -49.3498   70.2200      8.82        94          97
# 4              beau vallon -20.4298   57.7118     27.23        89          75
# 5             puerto ayora  -0.7472  -90.3134     31.34        87          64
# 6                adamstown -25.0667 -130.1002     25.28        78          82
# 8                 waitangi -35.2705  174.0805     22.53        92          27
#
#          Wind Speed Country        Date
# City_ID
# 2             14.97      TF  1708035968
# 4              2.06      MU  1708035969
# 5              2.68      EC  1708035970
# 6              2.92      PN  1708035971
# 8              2.60      NZ  1708035972

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_axis = np.array(northern_hemi_df['Lat'])
y_axis = np.array(northern_hemi_df['Max Temp'])
lin_regress_plot(x_axis, y_axis, 'Latitude', 'Max Temp', 'Northern Hemisphere Latitude vs Max Temperature', 10, -10)
# Out:
# The r-value is: -0.8290956210397649

# %%
# Linear regression on Southern Hemisphere
x_axis = np.array(southern_hemi_df['Lat'])
y_axis = np.array(southern_hemi_df['Max Temp'])
lin_regress_plot(x_axis, y_axis, 'Latitude', 'Max Temp', 'Southern Hemisphere Latitude vs Max Temperature', -50, 25)
# Out:
# The r-value is: 0.560349394734146

# %% [markdown]
# **Discussion about the linear relationship:** Max temp seems to decrese the further latitude is from 0

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = np.array(northern_hemi_df['Lat'])
y_axis = np.array(northern_hemi_df['Humidity'])
lin_regress_plot(x_axis, y_axis, 'Latitude', 'Humidity', 'Northern Hemisphere Latitude vs Humidity', 45, 25)
# Out:
# The r-value is: 0.34780320495996403

# %%
# Southern Hemisphere
x_axis = np.array(southern_hemi_df['Lat'])
y_axis = np.array(southern_hemi_df['Humidity'])
lin_regress_plot(x_axis, y_axis, 'Latitude', 'Humidity', 'Southern Hemisphere Latitude vs Humidity', -50, 41)
# Out:
# The r-value is: 0.454615771158483

# %% [markdown]
# **Discussion about the linear relationship:** Wide spread data with a slight increase. I dont think there is anything definitive

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = np.array(northern_hemi_df['Lat'])
y_axis = np.array(northern_hemi_df['Cloudiness'])
lin_regress_plot(x_axis, y_axis, 'Latitude', 'Cloudiness', 'Northern Hemisphere Latitude vs Cloudiness', 45, 42)
# Out:
# The r-value is: 0.21988466315995084

# %%
# Southern Hemisphere
x_axis = np.array(southern_hemi_df['Lat'])
y_axis = np.array(southern_hemi_df['Cloudiness'])
lin_regress_plot(x_axis, y_axis, 'Latitude', 'Cloudiness', 'Southern Hemisphere Latitude vs Cloudiness', -50, 21)
# Out:
# The r-value is: 0.29277420122957126

# %% [markdown]
# **Discussion about the linear relationship:** No real relationship between the two as data is widespread

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = np.array(northern_hemi_df['Lat'])
y_axis = np.array(northern_hemi_df['Wind Speed'])
lin_regress_plot(x_axis, y_axis, 'Latitude', 'Wind Speed', 'Northern Hemisphere Latitude vs Wind Speed', 10, 10)
# Out:
# The r-value is: -0.018941450626864437

# %%
# Southern Hemisphere
x_axis = np.array(southern_hemi_df['Lat'])
y_axis = np.array(southern_hemi_df['Wind Speed'])
lin_regress_plot(x_axis, y_axis, 'Latitude', 'Wind Speed', 'Southern Hemisphere Latitude vs Wind Speed', -50, 7)
# Out:
# The r-value is: -0.1775401830640646

# %% [markdown]
# **Discussion about the linear relationship:** Agian not much of a relationship as the data is widespread.
